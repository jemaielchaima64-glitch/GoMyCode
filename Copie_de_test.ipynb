# %% [markdown]
# <a href="https://colab.research.google.com/github/jemaielchaima64-glitch/GoMyCode/blob/master/Copie_de_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=10
y=3
print("x*y",y*x)
print("x//y",x//y)
# Out:
# x*y 30
# x//y 3

# %%
a=5
b=7
print ("a+b=",a+b)
# Out:
# a+b= 12
